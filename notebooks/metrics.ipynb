# %%
import sys
import os
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.predictive_models import (
    load_datasets,
    build_frequency_model,
    predict_frequency_model,
    build_sensationalism_model,
    predict_sensationalism_model,
    build_malicious_account_model,
    predict_malicious_account_model,
    build_naive_realism_model,
    predict_naive_realism_model,
    map_sensationalism_from_counts,
    map_naive_realism_from_sentiment
)

import pandas as pd
import json
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Ground Truth

# %%
ground_truth = pd.read_csv('../data/ground_truth.csv')
ground_truth.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    2
# 1  Trump is 'committed' to $2,000 tariff dividend...                    0
# 2  The longest US government shutdown in history ...                    0
# 3  Add AP News as your preferred source to see mo...                    0
# 4  Key Points Prop 50 passed in California, appro...                    1
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  0               2              2
# 1                  0               0              1
# 2                  0               0              1
# 3                  0               0              0
# 4                  0               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %%
ground_truth.statement[3]
# Out:
# 'Add AP News as your preferred source to see more of our stories on Google.\n\nAdd AP News on Google Add AP News as your preferred source to see more of our stories on Google. Share\n\nA mid-decade battle over congressional redistricting is playing out in state capitals, in courtrooms and on the ballot.\n\nThe efforts to redraw U.S. House districts for partisan advantage got jump-started when President Donald Trump called upon Republican-led Texas to reshape districts so that the GOP could win more seats in next year’s elections.\n\nSince then, lawmakers in Democratic-led California and Republican-led Missouri have approved revised districts, and officials in more states are considering it. Utah’s Republican-led Legislature endorsed an altered congressional map Monday — though in response to a court order, not Trump’s demands.\n\nU.S. House districts typically are redrawn once a decade, immediately after a census. But some states have no prohibition on doing it more frequently. And the U.S. Supreme Court has said there is no federal prohibition on political gerrymandering, in which districts are intentionally drawn to favor one party.\n\nThe stakes are high, because Democrats need to gain just three seats in the 2026 elections to take control of the House, which would allow them to impede Trump’s agenda. The president’s party historically has lost seats in midterm elections, a fate Trump is trying to avoid.\n\nTexas judges hear legal challenge to new districts\n\nFederal judges in Texas are considering a legal challenge to new congressional districts passed at Trump’s urging during a special legislative session in August. Civil rights groups and dozens of Black and Hispanic voters contend the new map intentionally reduces minority voters’ influence in violation of the 1965 Voting Rights Act and the U.S. Constitution. They want to prevent the new districts from being used.\n\nRepublicans hold 25 of the 38 congressional seats in Texas. The revised map could give Republicans a shot at picking up five additional seats in next year’s elections.\n\nCalifornia voters are deciding on new House districts\n\nVoting began Monday in California in advance of a Nov. 4 election that will determine whether new congressional districts are implemented.\n\nDemocrats already hold 43 of California’s 52 seats. But after Texas undertook redistricting, Democratic Gov. Gavin Newsom urged California lawmakers to reciprocate. They did so by passing a revised U.S. House map that could give Democrats a chance to gain five additional seats.\n\nUnlike Texas, California has an independent citizens’ commission that handles redistricting after the census. So any changes to the map need voter approval.\n\nMissouri redistricting faces potential referendum\n\nAfter Texas and California took action, Missouri lawmakers joined the redistricting battle by passing a revised U.S. House map designed to give Republicans a shot at winning seven of the state’s eight districts — one more than they currently hold. The map targets a seat held by Democratic Rep. Emanuel Cleaver by stretching the Kansas City-based district into rural Republican areas and reducing the number of minority voters.\n\nOpponents are pursuing a referendum petition that, if successful, would force a statewide vote on the new map. Opponents also have filed several lawsuits asserting that mid-decade redistricting isn’t allowed under the state constitution.\n\nUtah lawmakers back new US House map\n\nUtah’s Republican-led Legislature passed a revised U.S. House map Monday that could give Democrats an improved chance at competing for a seat. Republicans currently hold all four of the state’s seats.\n\nThe revised map would place Democratic-leaning Salt Lake City in a single district that stretches into rural areas, instead of splitting the city among multiple districts. But the revision still must be reviewed by a judge, who is expected to approve a new map by November.\n\nA Utah judge in August struck down ...

# %%
print(ground_truth.link[3])
# Out:
# https://apnews.com/article/redistricting-gerrymandering-congress-trump-0af8561b1670032fae3e1d2aec7905f0

# %% [markdown]
# # Predictive Models

# %%
train_path = "../data/train_set.csv"
val_path = "../data/val_set.csv"
test_path = "../data/test_set.csv"
df_train, df_val, df_test = load_datasets(
    train_path, val_path, test_path
)

# %% [markdown]
# ## Frequency Heuristic

# %% [markdown]
# ### LiarPLUS Accuracy

# %%
train_freq = df_train.copy()
val_freq   = df_val.copy()
test_freq  = df_test.copy()

# %%
model, tfidf, count_vec, token_dict, buzzwords, label_encoder = build_frequency_model(train_freq)

val_pred_freq = predict_frequency_model(val_freq, model, tfidf, count_vec, token_dict, buzzwords, label_encoder)
test_pred_freq = predict_frequency_model(test_freq, model, tfidf, count_vec, token_dict, buzzwords, label_encoder)

# %%
label_to_score = {
    "true": 2,
    "mostly-true": 2,
    "half-true": 1,
    "barely-true": 0,
    "false": 0,
    "pants-on-fire": 0
}

val_freq["frequency_heuristic"] = [label_to_score.get(lbl, 1) for lbl in val_freq["label"]]
test_freq["frequency_heuristic"] = [label_to_score.get(lbl, 1) for lbl in test_freq["label"]]

freq_val_accuracy = accuracy_score(val_freq["frequency_heuristic"], val_pred_freq["predicted_frequency_heuristic"])
freq_test_accuracy = accuracy_score(test_freq["frequency_heuristic"], test_pred_freq["predicted_frequency_heuristic"])

# %%
print("Frequency Heuristic Val Accuracy:", freq_val_accuracy)
print("Frequency Heuristic Test Accuracy:", freq_test_accuracy)
# Out:
# Frequency Heuristic Val Accuracy: 0.36751497005988026
# Frequency Heuristic Test Accuracy: 0.3769633507853403

# %% [markdown]
# ### Ground Truth Accuracy

# %%
freq_pred_ground_truth = predict_frequency_model(ground_truth, model, tfidf, count_vec, token_dict, buzzwords, label_encoder)

# %%
freq_accuracy = accuracy_score(ground_truth["frequency_heuristic"], freq_pred_ground_truth["predicted_frequency_heuristic"])
print("Frequency Heuristic Ground Truth Accuracy:", freq_accuracy)
# Out:
# Frequency Heuristic Ground Truth Accuracy: 0.05

# %% [markdown]
# ## Sensationliasm

# %% [markdown]
# ### LiarPLUS Accuracy

# %%
train_sens = df_train.copy()
val_sens   = df_val.copy()
test_sens  = df_test.copy()

# %%
sens_model, sens_numeric_features = build_sensationalism_model(train_sens)

val_pred_sens = predict_sensationalism_model(val_sens, sens_model, sens_numeric_features)
test_pred_sens = predict_sensationalism_model(test_sens, sens_model, sens_numeric_features)

# %%
val_sens["sensationalism"]  = val_sens.apply(map_sensationalism_from_counts, axis=1)
test_sens["sensationalism"] = test_sens.apply(map_sensationalism_from_counts, axis=1)

# %%
sens_val_accuracy = accuracy_score(val_sens["sensationalism"], val_pred_sens['predicted_sensationalism'])
sens_test_accuracy = accuracy_score(test_sens["sensationalism"], test_pred_sens['predicted_sensationalism'])

print("Sensationalism Val Accuracy:", sens_val_accuracy)
print("Sensationalism Test Accuracy:", sens_test_accuracy)
# Out:
# Sensationalism Val Accuracy: 0.5112275449101796
# Sensationalism Test Accuracy: 0.5130890052356021

# %% [markdown]
# ### Ground Truth Accuracy

# %%
sens_pred_ground_truth = predict_sensationalism_model(ground_truth, sens_model, sens_numeric_features)

# %%
sens_accuracy = accuracy_score(ground_truth["sensationalism"], sens_pred_ground_truth["predicted_sensationalism"])
print("Sensationalism Ground Truth Accuracy:", sens_accuracy)
# Out:
# Sensationalism Ground Truth Accuracy: 0.45

# %% [markdown]
# ## Malicious Account

# %% [markdown]
# ### LiarPLUS Accuracy

# %%
train_mal = df_train.copy()
val_mal   = df_val.copy()
test_mal  = df_test.copy()

# %%
mal_model, mal_tfidf, mal_le = build_malicious_account_model(train_mal)

# %%
val_pred_mal = predict_malicious_account_model(val_mal, mal_model, mal_tfidf, mal_le)
test_pred_mal = predict_malicious_account_model(test_mal, mal_model, mal_tfidf, mal_le)

# %%
label_to_score = {
    "true": 2,
    "mostly-true": 2,
    "half-true": 1,
    "barely-true": 0,
    "false": 0,
    "pants-on-fire": 0
}

val_mal["malicious_account"]  = [label_to_score.get(lbl, 1) for lbl in val_mal["label"]]
test_mal["malicious_account"] = [label_to_score.get(lbl, 1) for lbl in test_mal["label"]]

# %%
mal_val_accuracy = accuracy_score(val_mal["malicious_account"], val_pred_mal['predicted_malicious_account'])

mal_test_accuracy = accuracy_score(test_mal["malicious_account"], test_pred_mal['predicted_malicious_account'])

print("Malicious Account Val Accuracy:", mal_val_accuracy)
print("Malicious Account Test Accuracy:", mal_test_accuracy)
# Out:
# Malicious Account Val Accuracy: 0.35254491017964074
# Malicious Account Test Accuracy: 0.36350037397157814

# %% [markdown]
# ### Ground Truth Accuracy

# %%
mal_pred_ground_truth = predict_malicious_account_model(ground_truth, mal_model, mal_tfidf, mal_le)

# %%
mal_accuracy = accuracy_score(ground_truth["malicious_account"], mal_pred_ground_truth["predicted_malicious_account"])
print("Malicious Account Ground Truth Accuracy:", mal_accuracy)
# Out:
# Malicious Account Ground Truth Accuracy: 0.25

# %% [markdown]
# ## Naive Realism

# %% [markdown]
# ### LiarPLUS Accuracy

# %%
train_nr = df_train.copy()
val_nr   = df_val.copy()
test_nr  = df_test.copy()

# %%
naive_model, naive_numeric_features = build_naive_realism_model(train_nr)

# %%
val_pred_nr = predict_naive_realism_model(val_nr, naive_model, naive_numeric_features)
test_pred_nr = predict_naive_realism_model(test_nr, naive_model, naive_numeric_features)

# %%
val_nr["naive_realism"]  = val_nr["statement"].apply(map_naive_realism_from_sentiment)
test_nr["naive_realism"] = test_nr["statement"].apply(map_naive_realism_from_sentiment)

# %%
nr_val_accuracy = accuracy_score(val_nr["naive_realism"], val_pred_nr['predicted_naive_realism'])
nr_test_accuracy = accuracy_score(test_nr["naive_realism"], test_pred_nr['predicted_naive_realism'])

print("Naive Realism Val Accuracy:", nr_val_accuracy)
print("Naive Realism Test Accuracy:", nr_test_accuracy)
# Out:
# Naive Realism Val Accuracy: 0.6781437125748503
# Naive Realism Test Accuracy: 0.6768885564697082

# %% [markdown]
# ### Ground Truth Accuracy

# %%
nr_pred_ground_truth = predict_naive_realism_model(ground_truth, naive_model, naive_numeric_features)

# %%
nr_accuracy = accuracy_score(ground_truth["naive_realism"], nr_pred_ground_truth["predicted_naive_realism"])
print("Naive Realism Ground Truth Accuracy:", nr_accuracy)
# Out:
# Naive Realism Ground Truth Accuracy: 0.45

# %% [markdown]
# # GenAI

# %% [markdown]
# ## Base Prompt

# %%
base_df = pd.read_csv('../webapp/results/base_outputs.csv')
base_df
# Out:
#                                       id  \
# 0   e4fc0d08-70fb-47f3-b9f7-244fae6b6ac0
# 1   dcc96fd3-d309-4e77-a521-9b8cd1d97947
# 2   7044f906-1f3e-49be-af9c-9fbbc65b0a83
# 3   2920dab3-fbc3-4f8e-b3e6-3ff6724f0915
# 4   dc3c3657-889f-4578-baa9-117718901b0a
# 5   b642b598-66cb-4849-8819-63c306185f44
# 6   0902c539-592d-4f14-8f44-a464b0eda2b1
# 7   a6d5b685-7560-4e48-9a81-f51054552ea4
# 8   c28d3688-a232-4244-a640-4a85e530a602
# 9   dcf97a15-ebf8-4592-9de7-87601dbe8731
# 10  446139c1-15f8-4b0a-b374-d6d677f5a071
# 11  9553e705-442d-4707-879e-66c00e4cca19
# 12  fa931322-e54f-4520-8b6f-5855a8029bc0
# 13  d5d999df-6353-410f-aee4-cd1215f067ee
# 14  9d742352-4a61-4540-87cb-58aa0899bbad
# 15  c31dbb6b-f16c-411f-811c-27607bb4afed
# 16  f0f32cfa-9585-4a9f-a192-30a207eddca4
# 17  91d88107-9830-4a55-bf40-eecb3b5f1fd3
# 18  7ea7ea22-28b9-40bc-b379-75a0b525037a
# 19  0f5119e7-a710-41ff-ae39-00dc79283cde
#
#                                                   url  freq_score  \
# 0   https://www.cnn.com/2025/10/20/politics/trump-...           2
# 1   https://abc7.com/post/trump-is-committed-givin...           0
# 2   https://www.theguardian.com/us-news/2025/nov/1...           0
# 3   https://apnews.com/article/redistricting-gerry...           0
# 4   https://azcapitoltimes.com/news/2025/11/12/pro...           1
# 5   https://abcnews.go.com/Politics/house-vote-ful...           2
# 6   https://www.nbcnews.com/politics/politics-news...           1
# 7      https://www.bbc.com/news/articles/c4gpnz05kr8o           0
# 8   https://calmatters.org/commentary/2025/11/dana...           0
# 9   https://www.kff.org/racial-equity-and-health-p...           0
# 10  https://www.nytimes.com/2025/11/19/opinion/tru...           0
# 11  https://www.dailywire.com/news/musk-reveals-sh...           1
# 12  https://dppa.un.org/en/mtg-sc-10027-asg-pobee-...           0
# 13  https://www.cbsnews.com/news/epstein-accusers-...           1
# 14  https://www.dailymail.co.uk/sport/mlb/article-...           1
# 15  https://www.rollingstone.com/politics/politics...           1
# 16  https://www.vanityfair.com/news/story/gavin-ne...           0
# 17  https://www.scrippsnews.com/politics/immigrati...           1
# 18  https://www.foxnews.com/politics/trump-gave-ma...           2
# 19  https://www.politico.com/news/2025/11/30/jerse...           0
#
#                                           freq_reason  freq_confidence  \
# 0   The article consistently repeats the central c...               95
# 1   The article reports on a specific political pr...               95
# 2   The article does not exhibit significant repet...               95
# 3   The article's structure discusses the same top...              100
# 4   The article's central theme of a deepening pol...               90
# 5   The article exhibits heavy repetition. The pho...              100
# 6   The article's entire premise is built on an ap...               95
# 7   The article's claims are based on specific ale...               95
# 8   The article does not exhibit repetitive claims...               95
# 9   The article reports findings from a single sur...               95
# 10  The article does not rely on repetition of cla...               95
# 11  The term 'fraud' is repeated six times in the ...               90
# 12  The text repeats calls for peace and an end to...              100
# 13  The article reports on a unified message from ...               90
# 14  The article repeats the central claim that ICE...               90
# 15  The article consistently repeats the central c...               95
# 16  The article outlines a series of different eve...               95
# 17  The article repeatedly mentions fatal truck cr...               95
# 18  The article heavily and repeatedly pushes the ...               95
# 19  The article uses a comparison to a similar pol...               95
#
#     mal_score                                         mal_reason  \
# 0           0  The article itself, while highly partisan, fol...
# 1           0  The article cites multiple, credible, and name...
# 2           0  The article reads as a standard piece of polit...
# 3           0  The article is attributed to AP News (Associat...
# 4           0  The article attributes its information and quo...
# 5           2  The article contains multiple significant fact...
# 6           0  The article is attributed to NBC News, a well-...
# 7           0  The article is from the BBC and authored by na...
# 8           0  The article references verifiable sources such...
# 9           0  The article is explicitly sourced to the Kaise...
# 10          0  The text references known political figures an...
# 11          2  The article contains verifiable falsehoods, su...
# 12          0  The source is identified as a high-ranking UN ...
# 13          0  The article attributes all claims and quotes t...
# 14          0  The sources cited in the article are credible ...
# 15          0  The sources cited are primarily verifiable pub...
# 16          1  The article references anonymous but generally...
# 17          0  The sources cited are official and credible go...
# 18          2  The article is presented as a breaking news re...
# 19          0  The article is attributed to POLITICO, a reput...
#
#     mal_confidence  sens_score  \
# 0               90           2
# 1              100           1
# 2               98           1
# 3              100           0
# 4               95           1
# 5              100           1
# 6              100           1
# 7              100           1
# 8               95           1
# 9              100           1
# 10              90           1
# 11              95           2
# 12             100           1
# 13              95           1
# 14              95           2
# 15              90           2
# 16              90           1
# 17             100           2
# 18             100           2
# 19             100           1
#
#                                           sens_reason  sens_confidence  \
# 0   The text is saturated with dramatic, emotional...              100
# 1   The author's tone is generally neutral and rep...               90
# 2   The article uses some dramatic language to des...               90
# 3   The article maintains a neutral and factual to...               95
# 4   The language is generally analytical but uses ...               85
# 5   While the subject matter (Jeffrey Epstein) is ...               90
# 6   The article uses emotionally weighted language...               90
# 7   While the journalistic reporting is factual an...               90
# 8   The article uses some dramatic but largely des...               90
# 9   The article uses emotionally weighted language...               85
# 10  The article uses emotionally charged and drama...               90
# 11  The text uses dramatic and exaggerated languag...               95
# 12  The article uses strong and emotive words like...               95
# 13  The article contains strong, emotional languag...               85
# 14  The article quotes highly dramatic and emotion...               98
# 15  The article employs highly emotional and drama...              100
# 16  The text uses some engaging and slightly drama...               90
# 17  The article features highly emotional and accu...               95
# 18  The article uses highly dramatic, emotional, a...              100
# 19  The article employs moderately sensationalized...               90
#
#     naive_score                                       naive_reason  \
# 0             2  The article presents a single, un-nuanced pers...
# 1             0  The article presents a balanced view by includ...
# 2             0  The article presents a balanced view by includ...
# 3             0  The article presents a balanced view by report...
# 4             0  The article actively works against a simplisti...
# 5             0  The article presents a balanced view by includ...
# 6             0  The article actively presents a nuanced and ba...
# 7             0  The article demonstrates balance by presenting...
# 8             0  The article presents a balanced view by includ...
# 9             0  The article focuses on reporting the results o...
# 10            2  The article presents a highly one-sided interp...
# 11            2  The article presents its claims as absolute fa...
# 12            0  The text presents a nuanced view, acknowledgin...
# 13            0  The article demonstrates balance by including ...
# 14            2  The article exclusively presents the perspecti...
# 15            2  The article presents a single, highly critical...
# 16            1  The article is somewhat one-sided, framing New...
# 17            1  While the article includes quotes from both th...
# 18            2  The piece almost exclusively relies on a singl...
# 19            1  The text frames the political contest in a som...
#
#     naive_confidence  overall_confidence
# 0                 95               95.00
# 1                100               96.25
# 2                 99               95.50
# 3                100               98.75
# 4                 95               91.25
# 5                100               97.50
# 6                100               96.25
# 7                 95               95.00
# 8                100               95.00
# 9                 95               93.75
# 10                95               92.50
# 11                90               92.50
# 12               100               98.75
# 13                95               91.25
# 14                95               94.50
# 15               100               96.25
# 16                85               90.00
# 17                90               95.00
# 18                95               97.50
# 19                85               92.50

# %%
freq_acc  = (ground_truth["frequency_heuristic"] == base_df["freq_score"]).mean()
mal_acc   = (ground_truth["malicious_account"] == base_df["mal_score"]).mean()
sens_acc  = (ground_truth["sensationalism"] == base_df["sens_score"]).mean()
naive_acc = (ground_truth["naive_realism"] == base_df["naive_score"]).mean()

# %%
print("Frequency heuristic accuracy:", freq_acc)
print("Malicious account accuracy:", mal_acc)
print("Sensationalism accuracy:", sens_acc)
print("Naive Realism accuracy:", naive_acc)
# Out:
# Frequency heuristic accuracy: 0.6
# Malicious account accuracy: 0.8
# Sensationalism accuracy: 0.5
# Naive Realism accuracy: 0.65

# %% [markdown]
# ## Chain of Thought

# %%
cot_df = pd.read_csv('../webapp/results/cot_outputs.csv')
cot_df
# Out:
#                                       id  \
# 0   846eba04-9a07-4db2-8e2b-bd22b5e637ee
# 1   fc5d28a2-d97d-4b17-97ad-897599641450
# 2   486dca50-6def-4ed3-b9eb-378771925237
# 3   adb23f07-5f8c-45a7-8bd6-8ebac3e55e91
# 4   c94d27e2-2d60-45ed-99f6-99edf4e4db0d
# 5   f23bd343-374d-4442-bf09-1c42e7749dd0
# 6   2baed70e-45fe-4c96-b1d0-ea10e6bfaefd
# 7   f0d709d6-255f-4e98-89b0-2631eb21e6bd
# 8   f3b6ddef-0a3a-4070-92e5-7e692ec692e0
# 9   238b7d86-bf71-49dd-90f5-afdbea9427ea
# 10  7f0484ff-dd67-44d7-b265-a867d8617fce
# 11  d2d53ab5-eeb2-4b8a-890f-16eca844aee6
# 12  5bf2b181-e583-420a-a4a8-cbf1a56c596d
# 13  eea911f9-45b2-456e-afd0-591af8895b9f
# 14  bd0023ef-12c9-4d38-a8db-f1145f23141e
# 15  84b2de16-79f8-4c86-9bc4-f1f720516ccd
# 16  ee1a6548-d310-4ed3-bf05-ba9e6427b663
# 17  78276dc0-8350-472d-a8e4-f1658e34f89b
# 18  2cbd92b7-151c-491d-8354-54cc63a68293
# 19  aa9e3211-ad4a-4f0e-8580-6b6d5eaeb786
#
#                                                   url  freq_score  \
# 0   https://www.cnn.com/2025/10/20/politics/trump-...           2
# 1   https://abc7.com/post/trump-is-committed-givin...           0
# 2   https://www.theguardian.com/us-news/2025/nov/1...           0
# 3   https://apnews.com/article/redistricting-gerry...           0
# 4   https://azcapitoltimes.com/news/2025/11/12/pro...           1
# 5   https://abcnews.go.com/Politics/house-vote-ful...           0
# 6   https://www.nbcnews.com/politics/politics-news...           1
# 7      https://www.bbc.com/news/articles/c4gpnz05kr8o           1
# 8   https://calmatters.org/commentary/2025/11/dana...           0
# 9   https://www.kff.org/racial-equity-and-health-p...           0
# 10  https://www.nytimes.com/2025/11/19/opinion/tru...           1
# 11  https://www.dailywire.com/news/musk-reveals-sh...           2
# 12  https://dppa.un.org/en/mtg-sc-10027-asg-pobee-...           0
# 13  https://www.cbsnews.com/news/epstein-accusers-...           1
# 14  https://www.dailymail.co.uk/sport/mlb/article-...           1
# 15  https://www.rollingstone.com/politics/politics...           2
# 16  https://www.vanityfair.com/news/story/gavin-ne...           1
# 17  https://www.scrippsnews.com/politics/immigrati...           1
# 18  https://www.foxnews.com/politics/trump-gave-ma...           1
# 19  https://www.politico.com/news/2025/11/30/jerse...           1
#
#                                           freq_reason  freq_confidence  \
# 0   The article heavily repeats the central narrat...              100
# 1   The article reports on a specific policy propo...              100
# 2   The article reports on a singular event and it...              100
# 3   The article introduces a central theme—mid-dec...              100
# 4   The article consistently repeats and reinforce...               95
# 5   The article reports on a sequence of events (a...              100
# 6   The article repeatedly references a specific p...              100
# 7   The article reports on a central claim—that Ch...               95
# 8   The article reports on a specific event (a fed...              100
# 9   The article reports findings from a single, cl...              100
# 10  The article establishes and consistently reinf...               95
# 11  The article heavily relies on repetition of th...              100
# 12  The article is a formal address that presents ...              100
# 13  The article moderately repeats the central the...               95
# 14  The article structures its narrative by repeat...               95
# 15  The article heavily repeats the central claim ...               95
# 16  The article establishes and repeats the centra...               95
# 17  The article repeatedly mentions fatal crashes ...               95
# 18  The article repeatedly cites one expert, Vanes...               90
# 19  The article establishes and moderately repeats...               95
#
#     mal_score                                         mal_reason  \
# 0           2  The article is a piece of speculative fiction ...
# 1           0  The sources cited are all credible and clearly...
# 2           0  The article is a piece of standard political r...
# 3           0  The article attributes information to credible...
# 4           0  The article is presented as a piece of politic...
# 5           2  The article is highly deceptive as it contains...
# 6           2  The article is a piece of disinformation based...
# 7           0  The article's source is the BBC, a credible ne...
# 8           0  The article exhibits the characteristics of st...
# 9           0  The article is explicitly attributed to a part...
# 10          1  The source is presented as an opinion piece fr...
# 11          2  The source is clearly deceptive and fabricated...
# 12          0  The source is explicitly identified as the UN ...
# 13          0  The article is attributed to 'CBS News', a maj...
# 14          1  The sources cited (Mark Teixeira, a political ...
# 15          1  The article cites public figures, a journalist...
# 16          1  The article is published by a credible mainstr...
# 17          1  The sources cited are named government officia...
# 18          2  The most significant indicator of a malicious ...
# 19          0  The article is attributed to POLITICO, a well-...
#
#     mal_confidence  sens_score  \
# 0              100           2
# 1              100           1
# 2              100           1
# 3              100           1
# 4              100           0
# 5              100           0
# 6              100           1
# 7              100           1
# 8              100           1
# 9              100           1
# 10              90           2
# 11             100           2
# 12             100           1
# 13              90           1
# 14              90           2
# 15              90           2
# 16              90           1
# 17              95           2
# 18             100           2
# 19             100           1
#
#                                           sens_reason  sens_confidence  \
# 0   The article uses highly dramatic and exaggerat...              100
# 1   While the article's own prose is neutral and o...               95
# 2   While the headline is factual and the tone is ...               95
# 3   The tone is largely informational and objectiv...               95
# 4   The article maintains a neutral and analytical...               95
# 5   The article's tone is intentionally neutral an...               95
# 6   While the core subject matter—a political assa...               95
# 7   The subject matter (international espionage) i...               90
# 8   The article uses mildly sensational language t...               95
# 9   The article uses some emotionally charged lang...               95
# 10  The article uses highly dramatic and emotional...              100
# 11  The article is highly sensationalized. The hea...              100
# 12  The language is strong and emotionally charged...               95
# 13  The article itself is written in a relatively ...               95
# 14  The article heavily relies on quoting extremel...              100
# 15  The text uses highly emotional and exaggerated...              100
# 16  The headline 'Gavin Newsom Is Winning the “Att...               95
# 17  The article uses highly sensationalized langua...               90
# 18  The article uses highly dramatic and emotional...               95
# 19  The text uses mildly dramatic and emotionally ...               90
#
#     naive_score                                       naive_reason  \
# 0             2  The article presents its critical perspective ...
# 1             0  The article is a strong example of balanced re...
# 2             0  The article is well-balanced and explicitly pr...
# 3             0  The article presents a nuanced situation by re...
# 4             0  The article is highly balanced and nuanced, ex...
# 5             2  The article is fully dogmatic because it prese...
# 6             2  The article presents a completely fictional ev...
# 7             0  The article is well-balanced and does not pres...
# 8             0  The article, while presenting a strong narrati...
# 9             0  The article is a report on survey findings and...
# 10            2  The article presents its interpretation of eve...
# 11            2  The content presents a completely fabricated r...
# 12            0  The article does not present a one-sided view....
# 13            1  The article is somewhat one-sided, framing the...
# 14            2  The article presents a completely one-sided vi...
# 15            2  The article presents its perspective as the on...
# 16            0  The article is well-balanced and avoids a dogm...
# 17            0  The article is structured around the conflict ...
# 18            2  The article presents a single, one-sided persp...
# 19            1  The article presents a singular, strong narrat...
#
#     naive_confidence  overall_confidence
# 0                100              100.00
# 1                100               98.75
# 2                100               98.75
# 3                 90               96.25
# 4                100               97.50
# 5                 95               97.50
# 6                100               98.75
# 7                100               96.25
# 8                 95               97.50
# 9                100               98.75
# 10               100               96.25
# 11               100              100.00
# 12               100               98.75
# 13                90               92.50
# 14               100               96.25
# 15               100               96.25
# 16               100               95.00
# 17               100               95.00
# 18                95               95.00
# 19                90               93.75

# %%
cot_df.head()
# Out:
#                                      id  \
# 0  846eba04-9a07-4db2-8e2b-bd22b5e637ee
# 1  fc5d28a2-d97d-4b17-97ad-897599641450
# 2  486dca50-6def-4ed3-b9eb-378771925237
# 3  adb23f07-5f8c-45a7-8bd6-8ebac3e55e91
# 4  c94d27e2-2d60-45ed-99f6-99edf4e4db0d
#
#                                                  url  freq_score  \
# 0  https://www.cnn.com/2025/10/20/politics/trump-...           2
# 1  https://abc7.com/post/trump-is-committed-givin...           0
# 2  https://www.theguardian.com/us-news/2025/nov/1...           0
# 3  https://apnews.com/article/redistricting-gerry...           0
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...           1
#
#                                          freq_reason  freq_confidence  \
# 0  The article heavily repeats the central narrat...              100
# 1  The article reports on a specific policy propo...              100
# 2  The article reports on a singular event and it...              100
# 3  The article introduces a central theme—mid-dec...              100
# 4  The article consistently repeats and reinforce...               95
#
#    mal_score                                         mal_reason  \
# 0          2  The article is a piece of speculative fiction ...
# 1          0  The sources cited are all credible and clearly...
# 2          0  The article is a piece of standard political r...
# 3          0  The article attributes information to credible...
# 4          0  The article is presented as a piece of politic...
#
#    mal_confidence  sens_score  \
# 0             100           2
# 1             100           1
# 2             100           1
# 3             100           1
# 4             100           0
#
#                                          sens_reason  sens_confidence  \
# 0  The article uses highly dramatic and exaggerat...              100
# 1  While the article's own prose is neutral and o...               95
# 2  While the headline is factual and the tone is ...               95
# 3  The tone is largely informational and objectiv...               95
# 4  The article maintains a neutral and analytical...               95
#
#    naive_score                                       naive_reason  \
# 0            2  The article presents its critical perspective ...
# 1            0  The article is a strong example of balanced re...
# 2            0  The article is well-balanced and explicitly pr...
# 3            0  The article presents a nuanced situation by re...
# 4            0  The article is highly balanced and nuanced, ex...
#
#    naive_confidence  overall_confidence
# 0               100              100.00
# 1               100               98.75
# 2               100               98.75
# 3                90               96.25
# 4               100               97.50

# %%
freq_acc  = (ground_truth["frequency_heuristic"] == cot_df["freq_score"]).mean()
mal_acc   = (ground_truth["malicious_account"] == cot_df["mal_score"]).mean()
sens_acc  = (ground_truth["sensationalism"] == cot_df["sens_score"]).mean()
naive_acc = (ground_truth["naive_realism"] == cot_df["naive_score"]).mean()

# %%
print("Frequency heuristic accuracy:", freq_acc)
print("Malicious account accuracy:", mal_acc)
print("Sensationalism accuracy:", sens_acc)
print("Naive Realism accuracy:", naive_acc)
# Out:
# Frequency heuristic accuracy: 0.7
# Malicious account accuracy: 0.5
# Sensationalism accuracy: 0.3
# Naive Realism accuracy: 0.45

# %% [markdown]
# ## Function Calling

# %% [markdown]
# ## Fractal Chain of Thought
