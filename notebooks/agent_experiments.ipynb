# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Ground Truth

# %%
ground_truth_1 = pd.read_csv('../data/ground_truth.csv')
ground_truth_2 = pd.read_csv('../data/ground_truth_pt2.csv')

gt_df = pd.concat([ground_truth_1, ground_truth_2], ignore_index=True)

# %%
gt_df.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    2
# 1  Trump is 'committed' to $2,000 tariff dividend...                    0
# 2  The longest US government shutdown in history ...                    0
# 3  Add AP News as your preferred source to see mo...                    0
# 4  Key Points Prop 50 passed in California, appro...                    1
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  0               2              2
# 1                  0               0              1
# 2                  0               0              1
# 3                  0               0              0
# 4                  0               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %% [markdown]
# ## Base Prompt

# %% [markdown]
# model = gemini-3-flash-preview

# %%
base = pd.read_csv('../data/base_results.csv')
base.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    2
# 1  Trump is 'committed' to $2,000 tariff dividend...                    1
# 2  The longest US government shutdown in history ...                    2
# 3  Add AP News as your preferred source to see mo...                    2
# 4  Key Points Prop 50 passed in California, appro...                    2
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  2               2              1
# 1                  0               0              1
# 2                  2               1              0
# 3                  2               0              0
# 4                  2               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %%
base_freq_acc  = (gt_df["frequency_heuristic"] == base["frequency_heuristic"]).mean()
base_mal_acc   = (gt_df["malicious_account"] == base["malicious_account"]).mean()
base_sens_acc  = (gt_df["sensationalism"] == base["sensationalism"] ).mean()
base_naive_acc = (gt_df["naive_realism"] == base["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", base_freq_acc)
print("Malicious account accuracy:", base_mal_acc)
print("Sensationalism accuracy:", base_sens_acc)
print("Naive Realism accuracy:", base_naive_acc)
# Out:
# Frequency heuristic accuracy: 0.3
# Malicious account accuracy: 0.1
# Sensationalism accuracy: 0.425
# Naive Realism accuracy: 0.375

# %% [markdown]
# ## Chain of Thought

# %% [markdown]
# model = gemini-3-flash-preview

# %%
cot = pd.read_csv('../data/cot_results.csv')
cot.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    1
# 1  Trump is 'committed' to $2,000 tariff dividend...                    1
# 2  The longest US government shutdown in history ...                    1
# 3  Add AP News as your preferred source to see mo...                    1
# 4  Key Points Prop 50 passed in California, appro...                    1
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  2               2              1
# 1                  2               0              0
# 2                  2               1              0
# 3                  2               0              0
# 4                  2               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %%
cot_freq_acc  = (gt_df["frequency_heuristic"] == cot["frequency_heuristic"]).mean()
cot_mal_acc   = (gt_df["malicious_account"] == cot["malicious_account"]).mean()
cot_sens_acc  = (gt_df["sensationalism"] == cot["sensationalism"] ).mean()
cot_naive_acc = (gt_df["naive_realism"] == cot["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", cot_freq_acc)
print("Malicious account accuracy:", cot_mal_acc)
print("Sensationalism accuracy:", cot_sens_acc)
print("Naive Realism accuracy:", cot_naive_acc)
# Out:
# Frequency heuristic accuracy: 0.4
# Malicious account accuracy: 0.05
# Sensationalism accuracy: 0.575
# Naive Realism accuracy: 0.375

# %% [markdown]
# ## In Context Learning

# %% [markdown]
# model = gemini-3-flash-preview

# %%
icl = pd.read_csv('../data/icl_results.csv')
icl.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    2
# 1  Trump is 'committed' to $2,000 tariff dividend...                    0
# 2  The longest US government shutdown in history ...                    0
# 3  Add AP News as your preferred source to see mo...                    0
# 4  Key Points Prop 50 passed in California, appro...                    1
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  0               2              1
# 1                  0               0              0
# 2                  0               1              0
# 3                  0               0              0
# 4                  0               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %%
icl_freq_acc  = (gt_df["frequency_heuristic"] == icl["frequency_heuristic"]).mean()
icl_mal_acc   = (gt_df["malicious_account"] == icl["malicious_account"]).mean()
icl_sens_acc  = (gt_df["sensationalism"] == icl["sensationalism"] ).mean()
icl_naive_acc = (gt_df["naive_realism"] == icl["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", icl_freq_acc)
print("Malicious account accuracy:", icl_mal_acc)
print("Sensationalism accuracy:", icl_sens_acc)
print("Naive Realism accuracy:", icl_naive_acc)
# Out:
# Frequency heuristic accuracy: 0.675
# Malicious account accuracy: 0.55
# Sensationalism accuracy: 0.575
# Naive Realism accuracy: 0.45

# %% [markdown]
# ## Function Calling

# %% [markdown]
# model = gemini-3-flash-preview

# %%
func_calling = pd.read_csv('../data/function_calling_results.csv')
func_calling.head()
# Out:
#                                            statement  frequency_heuristic  \
# 0  A president steeped in constitutional lore mig...                    2
# 1  Trump is 'committed' to $2,000 tariff dividend...                    1
# 2  The longest US government shutdown in history ...                    1
# 3  Add AP News as your preferred source to see mo...                    1
# 4  Key Points Prop 50 passed in California, appro...                    1
#
#    malicious_account  sensationalism  naive_realism  \
# 0                  0               2              1
# 1                  0               0              0
# 2                  2               1              0
# 3                  2               1              0
# 4                  2               1              0
#
#                                                 link
# 0  https://www.cnn.com/2025/10/20/politics/trump-...
# 1  https://abc7.com/post/trump-is-committed-givin...
# 2  https://www.theguardian.com/us-news/2025/nov/1...
# 3  https://apnews.com/article/redistricting-gerry...
# 4  https://azcapitoltimes.com/news/2025/11/12/pro...

# %%
func_calling_freq_acc  = (gt_df["frequency_heuristic"] == func_calling["frequency_heuristic"]).mean()
func_calling_mal_acc   = (gt_df["malicious_account"] == func_calling["malicious_account"]).mean()
func_calling_sens_acc  = (gt_df["sensationalism"] == func_calling["sensationalism"] ).mean()
func_calling_naive_acc = (gt_df["naive_realism"] == func_calling["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", func_calling_freq_acc)
print("Malicious account accuracy:", func_calling_mal_acc)
print("Sensationalism accuracy:", func_calling_sens_acc)
print("Naive Realism accuracy:", func_calling_naive_acc)
# Out:
# Frequency heuristic accuracy: 0.525
# Malicious account accuracy: 0.125
# Sensationalism accuracy: 0.5
# Naive Realism accuracy: 0.4

# %% [markdown]
# ## Fractal Chain of Thought 1

# %% [markdown]
# model = gemini-2.5-flash-lite

# %%
fcot_1 = pd.read_csv('../data/fcot1_results.csv')

# %%
freq_acc  = (gt_df["frequency_heuristic"] == fcot_1["frequency_heuristic"]).mean()
mal_acc   = (gt_df["malicious_account"] == fcot_1["malicious_account"]).mean()
sens_acc  = (gt_df["sensationalism"] == fcot_1["sensationalism"] ).mean()
naive_acc = (gt_df["naive_realism"] == fcot_1["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", freq_acc)
print("Malicious account accuracy:", mal_acc)
print("Sensationalism accuracy:", sens_acc)
print("Naive Realism accuracy:", naive_acc)
# Out:
# Frequency heuristic accuracy: 0.2
# Malicious account accuracy: 0.775
# Sensationalism accuracy: 0.45
# Naive Realism accuracy: 0.4

# %%
og_fcot = gt_df.head(20)

# %%
freq_acc  = (ground_truth_1["frequency_heuristic"] == og_fcot["frequency_heuristic"]).mean()
mal_acc   = (ground_truth_1["malicious_account"] == og_fcot["malicious_account"]).mean()
sens_acc  = (ground_truth_1["sensationalism"] == og_fcot["sensationalism"] ).mean()
naive_acc = (ground_truth_1["naive_realism"] == og_fcot["naive_realism"]).mean()

# %%
print("Frequency heuristic accuracy:", freq_acc)
print("Malicious account accuracy:", mal_acc)
print("Sensationalism accuracy:", sens_acc)
print("Naive Realism accuracy:", naive_acc)
# Out:
# Frequency heuristic accuracy: 0.05
# Malicious account accuracy: 0.55
# Sensationalism accuracy: 0.7
# Naive Realism accuracy: 0.45

# %%
freq_scores = pd.DataFrame({
    'link': gt_df['link'],
    'ground_truth_fh': gt_df['frequency_heuristic'],
