# %%
import asyncio
import json
import pandas as pd

# %%
import sys
from pathlib import Path

REPO_ROOT = Path("/Users/amelialei/Multi-Agent-Misinformation-Analysis-System")
sys.path.insert(0, str(REPO_ROOT))

# %%
from ff_agents.orchestrator.agent import root_agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ff_agents.orchestrator.agent import root_agent
#
# File ~/Multi-Agent-Misinformation-Analysis-System/ff_agents/orchestrator/agent.py:3
#       1 from google.adk.agents import ParallelAgent
#       2 from google.adk.agents import SequentialAgent
# ----> 3 from frequency_heuristic_agent.agent import freq_heuristic_agent
#       4 from malicious_account_agent.agent import malicious_acc_agent
#       5 from naive_realism_agent.agent import naive_realism_agent
#
# ModuleNotFoundError: No module named 'frequency_heuristic_agent'
